# %% [markdown]
# <a href="https://colab.research.google.com/github/WardZid/IntroToCloud/blob/main/BraudeCloud6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# מבוא למחשוב ענן | שבוע 6

# %%
# !pip install requests beautifulsoup4
# !pip install firebase
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Collecting firebase
#   Downloading firebase-4.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from firebase) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2024.2.2)
# Installing collected packages: firebase
# Successfully installed firebase-4.0.1

# %%
#Prepare Firebase
from firebase import firebase
fbConn = firebase.FirebaseApplication('https://braudecloud-18-02-2024-default-rtdb.europe-west1.firebasedatabase.app/',None)

# %%
import requests
from bs4 import BeautifulSoup

def fetch_page(url):
  response = requests.get(url)
  if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup
  else:
    return None

# %%
import re
def index_words(soup):
    index = {}
    words = re.findall(r'\w+', soup.get_text())
    for word in words:
        word = word.lower()
        if word in index:
            index[word] += 1
        else:
            index[word] = 1
    #print(format_json(index))
    return index

# %%
def remove_stop_words(index):
  stop_words = {'a', 'an', 'the', 'and', 'or','in', 'on', 'at'}
  for stop_word in stop_words:
      if stop_word in index:
            del index[stop_word]
  return index

# %%
from nltk.stem import PorterStemmer
def apply_stemming(index):
    stemmer = PorterStemmer()
    stemmed_index = {}
    for word, count in index.items():
        stemmed_word = stemmer.stem(word)
        if stemmed_word in stemmed_index:
            stemmed_index[stemmed_word] += count
        else:
            stemmed_index[stemmed_word] = count
    return stemmed_index

# %%
def search(query, index):
    query_words = re.findall(r'\w+', query.lower())
    results = {}
    for word in query_words:
        if word in index:
            results[word] = index[word]
    return results

# %%
def search_engine(url, query):
    soup = fetch_page(url)
    if soup is None:
        return None
    index = index_words(soup)
    index = remove_stop_words(index)
    index = apply_stemming(index)
    results = search(query, index)
    return results

# %%
from urllib.parse import urlparse, urljoin
from collections import deque

# Function to extract links from a webpage
def extract_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = []
    for link in soup.find_all('a', href=True):
        links.append(link['href'])
    return links

# Function to check if links are from the same domain
def check_same_domain(base_url, links):
    base_domain = urlparse(base_url).netloc
    same_domain_links = []
    for link in links:
        parsed_link = urlparse(link)
        if parsed_link.netloc == base_domain or parsed_link.netloc == '':
            same_domain_links.append(link)
    return same_domain_links

def is_same_domain(base_url, url):
    base_domain = urlparse(base_url).netloc
    link_domain = urlparse(url).netloc
    return base_domain == link_domain

# %%
def fetch_page_title(url):
    soup = fetch_page(url)
    if soup:
        title_tag = soup.find('title')
        if title_tag:
            return title_tag.get_text()
    return None

# %%
import hashlib

def save_and_hash_url(url_to_hash):
  # Hash the URL using MD5 hashing algorithm
  hashed_url = hashlib.md5(url_to_hash.encode()).hexdigest()

  title = fetch_page_title(url_to_hash)
  data_to_upload = {
    'url': url_to_hash,
    'title': title
  }
  result = fbConn.put_async('/pages', hashed_url,data=data_to_upload)
  return hashed_url

# %%
import urllib.parse

def search_words(url,query_words):
  hashed_url = save_and_hash_url(url)
  #print(hashed_url)
  for query in query_words:
    result = search_engine(url, query)
    if result == {}:
      continue
    #print(result," ---- ",result[query])
    #data_to_upload ={
    #    'link': url,
    #    'count': result[query]
    #}
    data_to_upload = {
        'count': result[query]
    }
    result = fbConn.put_async('/index/' + query,hashed_url,data=data_to_upload)

# %%
#start_url = "https://www.tencent.com/en-us/"
#queries = ["tencent","tech","industry","partner","cloud","media","revenue","career","team","manage"]
#search_words(start_url,queries)
#search_words("https://www.tencent.com/en-us/sitemap.html",queries)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-4c717fe06325> in <cell line: 3>()
#       1 start_url = "https://www.tencent.com/en-us/"
#       2 queries = ["tencent","tech","industry","partner","cloud","media","revenue","career","team","manage"]
# ----> 3 search_words(start_url,queries)
#       4 #search_words("https://www.tencent.com/en-us/sitemap.html",queries)
#
# <ipython-input-82-df51600384ce> in search_words(url, query_words)
#       5   #print(hashed_url)
#       6   for query in query_words:
# ----> 7     result = search_engine(url, query)
#       8     if result == {}:
#       9       continue
#
# <ipython-input-8-50551e827015> in search_engine(url, query)
#       1 def search_engine(url, query):
# ----> 2     soup = fetch_page(url)
#       3     if soup is None:
#       4         return None
#       5     index = index_words(soup)
#
# <ipython-input-3-d49cfb318758> in fetch_page(url)
#       3
#       4 def fetch_page(url):
# ----> 5   response = requests.get(url)
#       6   if response.status_code == 200:
#       7     soup = BeautifulSoup(response.text, 'html.parser')
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
start_url = "https://www.tencent.com/en-us/"
queries = ["tencent","tech","partner","cloud","media","career"]
#queries = ["infrastructure","Development","production","holdings"]

###BFS

visited = set()
# Initialize a queue with first url
queue = deque([start_url])

#get the base domain to start from
#base_domain = urlparse(start_url).netloc

# Loop until the queue is empty
while queue:
  #get next url to search
  url = queue.popleft()
  # Skip if the URL has been visited before
  if url in visited:
      continue

  # mark visited
  visited.add(url)

  print("Visiting:", url)
  #Get all the links in this page
  links = extract_links(url)
  print("Links Extracted: ",len(links))

  #searching words and saving them to firebase

  search_words(url,queries)
  # Ppocess link
  for link in links:
    absolute_link = urljoin(url, link)

    if is_same_domain(start_url, absolute_link) and absolute_link not in visited:
      #add link to queue
      queue.append(absolute_link)
# Out:
# Visiting: https://www.tencent.com/en-us/
# Links Extracted:  105
# Visiting: https://www.tencent.com/en-us/index.html
# Links Extracted:  105
# Visiting: https://www.tencent.com/en-us/about.html
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/about.html#about-con-1
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/about.html#about-con-2
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/about.html#about-con-3
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/about.html#about-con-4
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/about.html#about-con-5
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/investors/board-members.html
# Links Extracted:  67
# Visiting: https://www.tencent.com/en-us/about.html#about-con-6
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/about.html#about-con-7
# Links Extracted:  69
# Visiting: https://www.tencent.com/en-us/business.html
# Links Extracted:  87
# Visiting: https://www.tencent.com/en-us/business.html?page-active=to-b
# Links Extracted:  87
# Visiting: https://www.tencent.com/en-us/business.html?page-active=innovation
# Links Extracted:  87
# Visiting: https://www.tencent.com/en-us/employees.html
# Links Extracted:  65
# Visiting: https://www.tencent.com/en-us/employees.html#staff-con-1
# Links Extracted:  65
# Visiting: https://www.tencent.com/en-us/employees.html#staff-con-2
# Links Extracted:  65
# Visiting: https://www.tencent.com/en-us/employees.html#staff-con-3
# Links Extracted:  65
# Visiting: https://www.tencent.com/en-us/employees.html#staff-con-4
# Links Extracted:  65
# Visiting: https://www.tencent.com/en-us/esg.html
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/esg.html#respon-con-1
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/esg.html#respon-con-2
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/esg.html#respon-con-3
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/esg.html#respon-con-6
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/esg.html#respon-con-7
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/investors.html
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/investors.html#investors-con-1
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/investors.html#investors-con-2
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/investors.html#investors-con-3
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/investors.html#investors-con-4
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/investors.html#investors-con-5
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/investors.html#investors-con-6
# Links Extracted:  99
# Visiting: https://www.tencent.com/en-us/media.html
# Links Extracted:  97
# Visiting: https://www.tencent.com/en-us/media/news.html?type=media
# Links Extracted:  1337
# Visiting: https://www.tencent.com/en-us/media/news.html?type=financial
# Links Extracted:  1337
# Visiting: https://www.tencent.com/en-us/media/perspective.html
# Links Extracted:  681
# Visiting: https://www.tencent.com/en-us/media/library.html
# Links Extracted:  126
# Visiting: https://www.tencent.com/en-us/articles/2201724.html
# Links Extracted:  76
# Visiting: https://www.tencent.com/en-us/articles/2
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-doctor.html
# Links Extracted:  79
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-hospital-guidance.html
# Links Extracted:  81
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-academic-communication.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-alliance-workshop.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-tencent-cloud.html
# Links Extracted:  78
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-tencent-meeting.html
# Links Extracted:  78
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-wecom.html
# Links Extracted:  78
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-response-handbook.html
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-donations.html
# Links Extracted:  77
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-donations-together-we-can.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/responsibility/combat-covid-19-science.html
# Links Extracted:  80
# Visiting: https://www.tencent.com/en-us/business/digital-ark-desc.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/supplier-privacy-policy.html
# Links Extracted:  95
# Visiting: https://www.tencent.com/en-us/privacy-policy.html#info-title
# Links Extracted:  77
# Visiting: https://www.tencent.com/en-us/media.html#media-con-1
# Links Extracted:  97
# Visiting: https://www.tencent.com/en-us/media.html#media-con-2
# Links Extracted:  97
# Visiting: https://www.tencent.com/en-us/media.html#media-con-3
# Links Extracted:  97
# Visiting: https://www.tencent.com/en-us/media.html#media-con-4
# Links Extracted:  97
# Visiting: https://www.tencent.com/legal/html/zh-cn/index.html
# Links Extracted:  5
# Visiting: https://www.tencent.com/en-us/esg/carbon-neutrality.html
# Links Extracted:  77
# Visiting: https://www.tencent.com/en-us/esg/environment/tencent-for-planet.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/esg/environment/tencent-light.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/esg/tech-accessibility.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/esg/data-privacy.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/responsibility/tencent-charity-foundation.html
# Links Extracted:  76
# Visiting: https://www.tencent.com/en-us/responsibility/fundraising-platform.html
# Links Extracted:  76
# Visiting: https://www.tencent.com/en-us/esg/99-giving-day.html
# Links Extracted:  72
# Visiting: https://www.tencent.com/en-us/responsibility/tencent-great-wall-restoration-project.html
# Links Extracted:  73
# Visiting: https://www.tencent.com/en-us/responsibility/wecounty.html
# Links Extracted:  75
# Visiting: https://www.tencent.com/en-us/responsibility/inspire-scientific-innovations.html
# Links Extracted:  75
# Visiting: https://www.tencent.com/en-us/responsibility/nurture-future-generations.html
# Links Extracted:  73
# Visiting: https://www.tencent.com/en-us/responsibility/support-start-up.html
# Links Extracted:  75
# Visiting: https://www.tencent.com/en-us/responsibility/grow-entrepreneurs.html
# Links Extracted:  73
# Visiting: https://www.tencent.com/en-us/esg/social/supply-chain.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/esg/social/diversity-equity-inclusion.html
# Links Extracted:  74
# Visiting: https://www.tencent.com/en-us/esg/social/data-security.html
# Links Extracted:  73
# Visiting: https://www.tencent.com/en-us/esg/social/customer-service.html
# Links Extracted:  73
# Visiting: https://www.tencent.com/attachments/ProceduresForShareholders_en.pdf
# Links Extracted:  0
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board7
# Links Extracted:  67
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board6
# Links Extracted:  67
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board4
# Links Extracted:  67
# Visiting: https://www.tencent.com/attachments/auditcommittee_en_2019.pdf
# Links Extracted:  0
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board8
# Links Extracted:  67
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board9
# Links Extracted:  67
# Visiting: https://www.tencent.com/attachments/E_Tencent_Terms of Reference_CGC_v_20210226.pdf
# Links Extracted:  0
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board2
# Links Extracted:  67
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board1
# Links Extracted:  67
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board5
# Links Extracted:  67
# Visiting: https://www.tencent.com/attachments/NominationCommittee_v2_en.pdf
# Links Extracted:  0
# Visiting: https://www.tencent.com/en-us/investors/board-members.html#board3
# Links Extracted:  67
# Visiting: https://www.tencent.com/attachments/TencentTaxStrategy_en.pdf
# Links Extracted:  0
# Visiting: https://www.tencent.com/en-us/anti-money-laundering-policy-statement.html
# Links Extracted:  66
# Visiting: https://www.tencent.com/en-us/sanctions-policy-statement.html
# Links Extracted:  66
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2022
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2021
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2020
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2019
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2018
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2017
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/esg/esg-reports.html#years_2016
# Links Extracted:  82
# Visiting: https://www.tencent.com/en-us/responsibility.html
# Links Extracted:  61
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-d3f62e3b2f04> in <cell line: 15>()
#      30   #searching words and saving them to firebase
#      31
# ---> 32   search_words(url,queries)
#      33   # Ppocess link
#      34   for link in links:
#
# <ipython-input-82-df51600384ce> in search_words(url, query_words)
#      14     #}
#      15     data_to_upload = {
# ---> 16         'count': result[query]
#      17     }
#      18     result = fbConn.put_async('/index/' + query,hashed_url,data=data_to_upload)
#
# TypeError: 'NoneType' object is not subscriptable
