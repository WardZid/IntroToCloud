# %% [markdown]
# <a href="https://colab.research.google.com/github/WardZid/IntroToCloud/blob/main/BraudeCloud1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Intro to cloud computing
# ---
# תירגול 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/Intro to cloud/students.txt'

with open(file_path, 'r') as file:
    #content = file.read()
    df = pd.read_csv(file_path, delimiter=';')

# Display the DataFrame
df
#print(content)
#file.close()
# Out:
#   FirstName     LastName                    BraudeEmail            Courses  \
# 0      Ward       Zidani     ward.zidani@e.braude.ac.il  16678,33743,99890
# 1   Jeffrey      Epstein    jeff.the.man@e.braude.ac.il             ,99890
# 2    George  The Curious  curious.george@e.braude.ac.il  16678,33743,99890
#
#                                       InterestingURL
# 0                                     www.google.com
# 1  https://aljazeera.com/news/2024/1/4/jeffrey-ep...
# 2                                   www.facebook.com

# %%
# @title ## Pick Student (you have to run to view result)


student_name = "Jeffrey" # @param ["","Ward","Jeffrey","George"]

row_to_print = df[df["FirstName"] == student_name]

row_to_print
# Out:
#   FirstName LastName                  BraudeEmail Courses  \
# 1   Jeffrey  Epstein  jeff.the.man@e.braude.ac.il  ,99890
#
#                                       InterestingURL
# 1  https://aljazeera.com/news/2024/1/4/jeffrey-ep...

# %%
# @title ## Pick Student (run once and use the widgets)
import pandas as pd
import ipywidgets as widgets
from IPython.display import display


dropdown = widgets.Dropdown(
    options=df['FirstName'].tolist(),
    value=df['FirstName'].iloc[0],
    description='Select a student:'
)
course_text = widgets.Text(description='Courses:')
update_button = widgets.Button(description="Update and Save")

display(dropdown,course_text,update_button)


def on_dropdown_change(change):
    selected_name = change.new
    selected_row = df[df['FirstName'] == selected_name]
    course_text.value = selected_row['Courses'].iloc[0]


def on_text_change(change):
    selected_name = dropdown.value
    # record the change
    df.loc[df['FirstName'] == selected_name, 'Courses'] = course_text.value

def on_button_click(b):
    #save to my drive as a csv style file
    df.to_csv(file_path, sep=';', index=False)


dropdown.observe(on_dropdown_change, names='value')
course_text.observe(on_text_change, names='value')
update_button.on_click(on_button_click)

#to trigger the onChange event
dropdown.value = df['FirstName'].iloc[1]
dropdown.value = df['FirstName'].iloc[0]
# Out:
# Dropdown(description='Select a student:', options=('Ward', 'Jeffrey', 'George'), value='Ward')
# Text(value='', description='Courses:')
# Button(description='Update and Save', style=ButtonStyle())
