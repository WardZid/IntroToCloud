# %% [markdown]
# <a href="https://colab.research.google.com/github/WardZid/IntroToCloud/blob/main/BraudeCloud2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Intro to cloud
# ---
# תירגול 2<br/>
# JSON

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/Intro to cloud/students.json'

with open(file_path, 'r') as file:
    df = pd.read_json(file_path)

# Display the DataFrame
df
# Out:
#    id  name  class              email
# 0   1  Ault      8  ault@pynative.com
# 1   2  john      8  jhon@pynative.com
# 2   3  josh      8  josh@pynative.com
# 3   4  emma      8  emma@pynative.com

# %%
# @title ## Pick Student (run once and use the widgets)
import pandas as pd
import ipywidgets as widgets
from IPython.display import display,clear_output


dropdown = widgets.Dropdown(
    options=df['name'].tolist(),
    value=df['name'].iloc[0],
    description='Select a student:'
)
class_text = widgets.Text(description='Class:')
update_button = widgets.Button(description="Update and Save")

display(dropdown,class_text,update_button)


def on_dropdown_change(change):
    selected_name = change.new
    selected_row = df[df['name'] == selected_name]
    class_text.value = str(selected_row['class'].iloc[0])


def on_text_change(change):
    selected_name = dropdown.value
    try:
        # record the change
        df.loc[df['name'] == selected_name, 'class'] = int(class_text.value)
        print("Valid value recorded, click save to save to Google Drive")
    except ValueError:
        print("Invalid value X")



def on_button_click(b):
    #save to my drive as a json file
    df.to_json(file_path, orient='records', lines=True)


dropdown.observe(on_dropdown_change, names='value')
class_text.observe(on_text_change, names='value')
update_button.on_click(on_button_click)

#to trigger the onChange event
dropdown.value = df['name'].iloc[1]
dropdown.value = df['name'].iloc[0]
# Out:
# Dropdown(description='Select a student:', options=('Ault', 'john', 'josh', 'emma'), value='Ault')
# Text(value='', description='Class:')
# Button(description='Update and Save', style=ButtonStyle())
# Valid value recorded, click save to save to Google Drive
# Valid value recorded, click save to save to Google Drive
# Invalid value X
# Valid value recorded, click save to save to Google Drive
# Valid value recorded, click save to save to Google Drive
# Valid value recorded, click save to save to Google Drive
# Valid value recorded, click save to save to Google Drive
